# %% [markdown]
# # Intermediate Python

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
gapminder = pd.read_csv('data/gapminder.csv', index_col=0)
print(gapminder.shape)
print(gapminder.columns)
print(gapminder.info())
print(gapminder.describe())
print(gapminder.head())
print(gapminder.tail())
# Out:
# (142, 6)
# Index(['country', 'year', 'population', 'cont', 'life_exp', 'gdp_cap'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142 entries, 11 to 1703
# Data columns (total 6 columns):
# country       142 non-null object
# year          142 non-null int64
# population    142 non-null float64
# cont          142 non-null object
# life_exp      142 non-null float64
# gdp_cap       142 non-null float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 7.8+ KB
# None
#          year    population    life_exp       gdp_cap
# count   142.0  1.420000e+02  142.000000    142.000000
# mean   2007.0  4.402122e+07   67.007423  11680.071820
# std       0.0  1.476214e+08   12.073021  12859.937337
# min    2007.0  1.995790e+05   39.613000    277.551859
# 25%    2007.0  4.508034e+06   57.160250   1624.842248
# 50%    2007.0  1.051753e+07   71.935500   6124.371109
# 75%    2007.0  3.121004e+07   76.413250  18008.835640
# ...

# %%
plt.scatter('gdp_cap', 'life_exp', data=gapminder)
plt.xscale('log')

# %%
plt.scatter('population', 'life_exp', data=gapminder)

# %%
plt.hist('life_exp', data=gapminder)
# Out:
# (array([ 8.,  7., 10., 10., 10.,  8.,  5., 33., 23., 28.]),
#  array([39.613, 43.912, 48.211, 52.51 , 56.809, 61.108, 65.407, 69.706,
#         74.005, 78.304, 82.603]),
#  <a list of 10 Patch objects>)

# %%
plt.hist('life_exp', data=gapminder, bins=5)
plt.show()
plt.clf()

plt.hist('life_exp', data=gapminder, bins=20)
# Out:
# (array([ 1.,  7.,  2.,  5.,  4.,  6.,  5.,  5.,  4.,  6.,  3.,  5.,  5.,
#          0., 12., 21., 13., 10., 17., 11.]),
#  array([39.613 , 41.7625, 43.912 , 46.0615, 48.211 , 50.3605, 52.51  ,
#         54.6595, 56.809 , 58.9585, 61.108 , 63.2575, 65.407 , 67.5565,
#         69.706 , 71.8555, 74.005 , 76.1545, 78.304 , 80.4535, 82.603 ]),
#  <a list of 20 Patch objects>)

# %%
plt.hist('life_exp', data=gapminder, bins=15)
plt.show()
plt.clf()

life_exp = [28.8, 55.23, 43.08, 30.02, 62.48, 69.12, 66.8, 50.94, 37.48, 68.0, 38.22, 40.41, 53.82, 47.62, 50.92, 59.6, 31.98, 39.03, 39.42, 38.52, 68.75, 35.46, 38.09, 54.74, 44.0, 50.64, 40.72, 39.14, 42.11, 57.21, 40.48, 61.21, 59.42, 66.87, 70.78, 34.81, 45.93, 48.36, 41.89, 45.26, 34.48, 35.93, 34.08, 66.55, 67.41, 37.0, 30.0, 67.5, 43.15, 65.86, 42.02, 33.61, 32.5, 37.58, 41.91, 60.96, 64.03, 72.49, 37.37, 37.47, 44.87, 45.32, 66.91, 65.39, 65.94, 58.53, 63.03, 43.16, 42.27, 50.06, 47.45, 55.56, 55.93, 42.14, 38.48, 42.72, 36.68, 36.26, 48.46, 33.68, 40.54, 50.99, 50.79, 42.24, 59.16, 42.87, 31.29, 36.32, 41.72, 36.16, 72.13, 69.39, 42.31, 37.44, 36.32, 72.67, 37.58, 43.44, 55.19, 62.65, 43.9, 47.75, 61.31, 59.82, 64.28, 52.72, 61.05, 40.0, 46.47, 39.88, 37.28, 58.0, 30.33, 60.4, 64.36, 65.57, 32.98, 45.01, 64.94, 57.59, 38.64, 41.41, 71.86, 69.62, 45.88, 58.5, 41.22, 50.85, 38.6, 59.1, 44.6, 43.58, 39.98, 69.18, 68.44, 66.07, 55.09, 40.41, 43.16, 32.55, 42.04, 48.45]
plt.hist(life_exp, bins=15)
# Out:
# (array([ 5.,  8., 14., 17., 20., 11.,  7.,  7.,  4.,  7.,  9.,  6., 11.,
#         11.,  5.]),
#  array([28.8       , 31.72466667, 34.64933333, 37.574     , 40.49866667,
#         43.42333333, 46.348     , 49.27266667, 52.19733333, 55.122     ,
#         58.04666667, 60.97133333, 63.896     , 66.82066667, 69.74533333,
#         72.67      ]),
#  <a list of 15 Patch objects>)

# %%
gapminder['color'] = gapminder['cont'].map({
    'Asia':'red',
    'Europe':'green',
    'Africa':'blue',
    'Americas':'yellow',
    'Oceania':'black'
})
plt.scatter('gdp_cap', 'life_exp', data=gapminder, c='color', alpha=0.8)
plt.xscale('log')
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000], ['1k', '10k', '100k'])
plt.show()

# %%
cars = pd.read_csv('data/cars.csv', index_col=0)
print(cars.shape)
print(cars.columns)
print(cars.info())
print(cars.describe())
print(cars.head())
print(cars.tail())
# Out:
# (7, 3)
# Index(['cars_per_cap', 'country', 'drives_right'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, US to EG
# Data columns (total 3 columns):
# cars_per_cap    7 non-null int64
# country         7 non-null object
# drives_right    7 non-null bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 175.0+ bytes
# None
#        cars_per_cap
# count      7.000000
# mean     351.571429
# std      345.595552
# min       18.000000
# 25%       57.500000
# 50%      200.000000
# 75%      659.500000
# max      809.000000
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
#      cars_per_cap  country  drives_right
# JAP           588    Japan         False
# IN             18    India         False
# ...

# %%
brics = pd.read_csv('data/brics.csv', index_col=0)
print(brics.shape)
print(brics.columns)
print(brics.info())
print(brics.describe())
print(brics.head())
print(brics.tail())
# Out:
# (5, 4)
# Index(['country', 'capital', 'area', 'population'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, BR to SA
# Data columns (total 4 columns):
# country       5 non-null object
# capital       5 non-null object
# area          5 non-null float64
# population    5 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 200.0+ bytes
# None
#             area   population
# count   5.000000     5.000000
# mean    7.944000   601.176000
# std     6.200557   645.261454
# min     1.221000    52.980000
# 25%     3.286000   143.500000
# 50%     8.516000   200.400000
# 75%     9.597000  1252.000000
# max    17.100000  1357.000000
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98
# ...

# %%
import numpy as np
np.random.seed(123)
print(np.random.rand())
# Out:
# 0.6964691855978616

# %%
np.random.seed(123)
print(np.random.randint(1, 7))
# Out:
# 6

# %%
print(np.random.randint(1, 7))
# Out:
# 3

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(123)
all_walks = []

# Simulate random walk 50 times
for i in range(50) :
    random_walk = [0]
    for x in range(50) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)

        # Implement clumsiness
        if np.random.rand() < 0.001 :
            step = 0

        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
plt.plot(np_aw_t)
plt.show()
