# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
nohitter_times = np.array([ 
        843, 1613, 1101,  215,  684,  814,  278,  324,  161,  219,  545,
        715,  966,  624,   29,  450,  107,   20,   91, 1325,  124, 1468,
        104, 1309,  429,   62, 1878, 1104,  123,  251,   93,  188,  983,
        166,   96,  702,   23,  524,   26,  299,   59,   39,   12,    2,
        308, 1114,  813,  887,  645, 2088,   42, 2090,   11,  886, 1665,
       1084, 2900, 2432,  750, 4021, 1070, 1765, 1322,   26,  548, 1525,
         77, 2181, 2752,  127, 2147,  211,   41, 1575,  151,  479,  697,
        557, 2267,  542,  392,   73,  603,  233,  255,  528,  397, 1529,
       1023, 1194,  462,  583,   37,  943,  996,  480, 1497,  717,  224,
        219, 1531,  498,   44,  288,  267,  600,   52,  269, 1086,  386,
        176, 2199,  216,   54,  675, 1243,  463,  650,  171,  327,  110,
        774,  509,    8,  197,  136,   12, 1124,   64,  380,  811,  232,
        192,  731,  715,  226,  605,  539, 1491,  323,  240,  179,  702,
        156,   82, 1397,  354,  778,  603, 1001,  385,  986,  203,  149,
        576,  445,  180, 1403,  252,  675, 1351, 2983, 1568,   45,  899,
       3260, 1025,   31,  100, 2055, 4043,   79,  238, 3931, 2351,  595,
        110,  215,    0,  563,  206,  660,  242,  577,  179,  157,  192,
        192, 1848,  792, 1693,   55,  388,  225, 1134, 1172, 1555,   31,
       1582, 1044,  378, 1687, 2915,  280,  765, 2819,  511, 1521,  745,
       2491,  580, 2072, 6450,  578,  745, 1075, 1103, 1549, 1520,  138,
       1202,  296,  277,  351,  391,  950,  459,   62, 1056, 1128,  139,
        420,   87,   71,  814,  603, 1349,  162, 1027,  783,  326,  101,
        876,  381,  905,  156,  419,  239,  119,  129,  467
])
len(nohitter_times)
# Out:
# 251

# %%
nohitters = pd.read_csv('mlb_nohitters.csv')
nohitters
# Out:
#          date  game_number winning_team losing_team    winning_pitcher
# 0    18760715          140          NaN         NaN                NaN
# 1    18800612         1035          NaN         NaN                NaN
# 2    18800617         1046          NaN         NaN                NaN
# 3    18800819         1177          NaN         NaN                NaN
# 4    18800820         1179          NaN         NaN                NaN
# 5    18820911         2114          NaN         NaN                NaN
# 6    18820919         2144          NaN         NaN                NaN
# 7    18820920         2151          NaN         NaN                NaN
# 8    18830725         2637          NaN         NaN                NaN
# 9    18830913         2892          NaN         NaN                NaN
# 10   18840529         3265          NaN         NaN                NaN
# 11   18840605         3347          NaN         NaN                NaN
# 12   18840627         3539          NaN         NaN                NaN
# 13   18840804         3895          NaN         NaN                NaN
# 14   18840826         4076          NaN         NaN                NaN
# 15   18840928         4363          NaN         NaN                NaN
# 16   18841004         4411          NaN         NaN                NaN
# 17   18850524         4681          NaN         NaN                NaN
# 18   18850727         5043          NaN         NaN                NaN
# 19   18850829         5217          NaN         NaN                NaN
# 20   18860501         5464          NaN         NaN                NaN
# 21   18860724         5957          NaN         NaN                NaN
# 22   18861006         6420          NaN         NaN                NaN
# 23   18880527         7740          NaN         NaN                NaN
# 24   18880606         7799          NaN         NaN                NaN
# 25   18880726         8097          NaN         NaN                NaN
# 26   18880731         8129          NaN         NaN                NaN
# 27   18900915        11100          NaN         NaN                NaN
# 28   18910622        11741          NaN         NaN                NaN
# 29   18910731        11979          NaN         NaN                NaN
# ..        ...          ...          ...         ...                ...
# 264  20100509       196932          OAK         TBA      Dallas Braden
# 265  20100529       197210          PHI         FLO       Roy Halladay
# 266  20100625       197562          ARI         TBA      Edwin Jackson
# 267  20100726       197954          TBA         DET         Matt Garza
# 268  20101006       198905          PHI         CIN       Roy Halladay
# 269  20110503       199365          MIN         CHA  Francisco Liriano
# 270  20110507       199428          DET         TOR   Justin Verlander
# 271  20110727       200485          ANA         CLE      Ervin Santana
# 272  20120421       201614          CHA         SEA      Philip Humber
# 273  20120502       201754          ANA         MIN       Jered Weaver
# 274  20120601       202175          NYN         SLN      Johan Santana
# 275  20120608       202263          SEA         LAN      Stephen Pryor
# 276  20120613       202335          SFN         HOU          Matt Cain
# 277  20120815       203150          SEA         TBA    Felix Hernandez
# 278  20120928       203754          CIN         PIT       Homer Bailey
# 279  20130702       205104          CIN         SFN       Homer Bailey
# 280  20130713       205267          SFN         SDN       Tim Lincecum
# 281  20130929       206295          MIA         DET  Henderson Alvarez
# 282  20140525       207079          LAN         PHI       Josh Beckett
# 283  20140618       207406          LAN         COL    Clayton Kershaw
# 284  20140625       207508          SFN         SDN       Tim Lincecum
# 285  20140901       208385          PHI         ATL        Cole Hamels
# 286  20140928       208767          WAS         MIA  Jordan Zimmermann
# 287  20150609       209673          SFN         NYN       Chris Heston
# 288  20150620       209830          WAS         PIT       Max Scherzer
# 289  20150725       210250          PHI         CHN        Cole Hamels
# 290  20150812       210490          SEA         BAL    Hisashi Iwakuma
# 291  20150821       210610          HOU         LAN      Michael Fiers
# 292  20150830       210740          CHN         LAN       Jake Arrieta
# 293  20151003       211208          WAS         NYN       Max Scherzer
#
# [294 rows x 5 columns]

# %%
((nohitters.game_number.diff()[43:] - 1) == nohitter_times).all()
# Out:
# True

# %%
np.random.seed(42)
tau = np.mean(nohitter_times)
tau
# Out:
# 763.0358565737051

# %%
inter_nohitter_time = np.random.exponential(tau, 100000)

# %%
plt.hist(inter_nohitter_time, bins=50, normed=True, histtype='step')
plt.xlabel('Games between no-hitters')
plt.ylabel('PDF')
plt.show()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   """Entry point for launching an IPython kernel.

# %%
def ecdf(data):
    return np.sort(data), np.arange(1, len(data)+1) / len(data)

# %%
x, y = ecdf(nohitter_times)
x_, y_ = ecdf(inter_nohitter_time)
plt.plot(x_, y_)
plt.plot(x, y, marker='.', linestyle='none')
plt.margins(0.02)
plt.xlabel('Games between no-hitters')
plt.ylabel('CDF')
plt.show()

# %%
plt.plot(x_, y_)
plt.plot(x, y, marker='.', linestyle='none')
plt.margins(0.02)
plt.xlabel('Games between no-hitters')
plt.ylabel('CDF')

samples_half = np.random.exponential(tau/2., 10000)
samples_double = np.random.exponential(tau*2., 10000)
x_h, y_h = ecdf(samples_half)
x_d, y_d = ecdf(samples_double)

plt.plot(x_h, y_h, color='green')
plt.plot(x_d, y_d, color='red')
plt.show()

# %%
import pandas as pd

female = pd.read_csv('female_literacy_fertility.csv')
female
# Out:
#                               Country  Continent  female literacy  fertility  \
# 0                                Chine       ASI             90.5      1.769
# 1                                 Inde       ASI             50.8      2.682
# 2                                  USA       NAM             99.0      2.077
# 3                            Indonésie       ASI             88.8      2.132
# 4                               Brésil       LAT             90.2      1.827
# 5                             Pakistan       ASI             40.0      3.872
# 6                           Bangladesh       ASI             49.8      2.288
# 7                              Nigéria        AF             48.8      5.173
# 8                 Fédération de Russie       EUR             99.4      1.393
# 9                                Japan       ASI             99.0      1.262
# 10                             Mexique       LAT             91.5      2.156
# 11                         Philippines       ASI             93.9      3.026
# 12                            Viet Nam       ASI             90.2      2.033
# 13                             Germany       EUR             99.0      1.324
# 14                              Egypte        AF             57.8      2.816
# 15                            Ethiopie        AF             22.8      5.211
# 16                             Turquie       ASI             81.3      2.100
# 17       Iran, République islamique d'       ASI             77.2      1.781
# 18                           Thaïlande       ASI             91.5      1.822
# 19          Rép. Démocratique du Congo        AF             56.1      5.908
# 20                              France       EUR             99.0      1.881
# 21                                  UK       EUR             99.0      1.852
# 22                              Italie       EUR             98.5      1.390
# 23                             Myanmar       ASI             89.2      2.281
# 24                      Afrique du Sud        AF             88.1      2.505
# 25                         South Korea       ASI             96.6      1.224
# 26                             Ukraine       EUR             99.6      1.361
# 27                             Espagne       EUR             96.9      1.468
# 28                            Colombie       LAT             93.4      2.404
# 29         République-Unie de Tanzanie        AF             66.3      5.520
# ..                                 ...       ...              ...        ...
# 132                            Lesotho        AF             95.1      3.264
# 133  L'ex-Rép. yougoslave de Macédoine       EUR             95.4      1.436
# 134                           Slovénie       EUR             99.7      1.393
# 135                           Botswana        AF             83.5      2.822
# 136                             Gambie        AF             34.3      4.969
# 137                      Guinée-Bissau        AF             36.5      5.659
# 138                              Gabon        AF             83.2      3.240
# 139                            Estonie       EUR             99.8      1.693
# 140                  Trinité-et-Tobago       LAT             98.2      1.647
# 141                              Qatar       ASI             90.4      2.360
# 142                            Maurice        AF             84.8      1.792
# 143                          Swaziland        AF             85.6      3.450
# 144                             Chypre       EUR             96.7      1.516
# 145                            Bahreïn       ASI             89.4      2.233
# 146                            Bhoutan       ASI             38.7      2.563
# 147                 Guinée équatoriale        AF             89.1      5.283
# 148                            Comores        AF             67.8      3.885
# 149                       Macao, Chine       ASI             90.7      0.966
# 150                           Suriname       LAT             88.4      2.373
# 151                           Cap-Vert        AF             79.3      2.663
# 152                              Malte       EUR             93.5      1.251
# 153                  Brunéi Darussalam       ASI             93.3      2.052
# 154                            Bahamas       LAT             96.5      3.371
# 155                            Iceland       EUR             99.0      2.093
# 156                           Maldives       ASI             98.4      2.000
# 157                            Vanuatu       OCE             79.5      3.883
# 158                              Samoa       OCE             98.5      3.852
# 159               Sao Tomé-et-Principe        AF             83.3      3.718
# 160                              Aruba       LAT             98.0      1.732
# 161                              Tonga       ASI             99.1      3.928
#
#         population
# 0    1,324,655,000
# 1    1,139,964,932
# 2      304,060,000
# 3      227,345,082
# 4      191,971,506
# 5      166,111,487
# 6      160,000,128
# 7      151,212,254
# 8      141,950,000
# 9      127,704,000
# 10     106,350,434
# 11      90,348,437
# 12      86,210,781
# 13      82,110,097
# 14      81,527,172
# 15      80,713,434
# 16      73,914,260
# 17      71,956,322
# 18      67,386,383
# 19      64,256,635
# 20      62,277,432
# 21      61,414,062
# 22      59,832,179
# 23      49,563,019
# 24      48,687,000
# 25      48,607,000
# 26      46,258,200
# 27      45,555,716
# 28      45,012,096
# 29      42,483,923
# ..             ...
# 132      2,049,429
# 133      2,041,342
# 134      2,021,316
# 135      1,921,122
# 136      1,660,200
# 137      1,575,446
# 138      1,448,159
# 139      1,340,675
# 140      1,333,388
# 141      1,280,862
# 142      1,268,854
# 143      1,167,834
# 144        862,434
# 145        775,585
# 146        686,789
# 147        659,197
# 148        643,571
# 149        526,178
# 150        515,124
# 151        498,672
# 152        411,950
# 153        392,280
# 154        337,668
# 155        317,414
# 156        305,027
# 157        233,866
# 158        178,869
# 159        160,174
# 160        105,455
# 161        103,566
#
# [162 rows x 5 columns]

# %%
illiteracy = 100 - female['female literacy']
plt.plot(illiteracy, female.fertility, marker='.', linestyle='none')
plt.margins(0.02)
plt.xlabel('percent illiterate')
plt.ylabel('fertility')
plt.show()

# %%
from scipy.stats import pearsonr

print(pearsonr(illiteracy, female.fertility)[0])
# Out:
# 0.8041324026815344

# %%
plt.plot(illiteracy, female.fertility, marker='.', linestyle='none')
plt.margins(0.02)
plt.xlabel('percent illiterate')
plt.ylabel('fertility')
a, b = np.polyfit(illiteracy, female.fertility, 1)
print('slope =', a, 'children per woman / percent illiterate')
print('intercept =', b, 'children per woman')
x = np.array([0, 100])
y = a * x + b
plt.plot(x, y)
plt.show()
# Out:
# slope = 0.04979854809063423 children per woman / percent illiterate
# intercept = 1.888050610636557 children per woman

# %%
a_ = np.linspace(0, 0.1, 200)
rss = np.empty_like(a_)
for i, a in enumerate(a_):
    rss[i] = np.sum((female.fertility - a * illiteracy - b)**2)
    
plt.plot(a_, rss, '-')
plt.xlabel('slope (children per woman/percent illiterate)')
plt.ylabel('sum of square of residuals')
plt.show()

# %%
anscombe = pd.read_csv('anscombe.csv', header=[0, 1])
anscombe
# Out:
#        0            1           2            3
#        x      y     x     y     x      y     x      y
# 0   10.0   8.04  10.0  9.14  10.0   7.46   8.0   6.58
# 1    8.0   6.95   8.0  8.14   8.0   6.77   8.0   5.76
# 2   13.0   7.58  13.0  8.74  13.0  12.74   8.0   7.71
# 3    9.0   8.81   9.0  8.77   9.0   7.11   8.0   8.84
# 4   11.0   8.33  11.0  9.26  11.0   7.81   8.0   8.47
# 5   14.0   9.96  14.0  8.10  14.0   8.84   8.0   7.04
# 6    6.0   7.24   6.0  6.13   6.0   6.08   8.0   5.25
# 7    4.0   4.26   4.0  3.10   4.0   5.39  19.0  12.50
# 8   12.0  10.84  12.0  9.13  12.0   8.15   8.0   5.56
# 9    7.0   4.82   7.0  7.26   7.0   6.42   8.0   7.91
# 10   5.0   5.68   5.0  4.74   5.0   5.73   8.0   6.89

# %%
anscombe.columns
# Out:
# MultiIndex(levels=[['0', '1', '2', '3'], ['x', 'y']],
#            codes=[[0, 0, 1, 1, 2, 2, 3, 3], [0, 1, 0, 1, 0, 1, 0, 1]])

# %%
idx = pd.IndexSlice
anscombe.loc[:, idx['0', 'x']]
# Out:
# 0     10.0
# 1      8.0
# 2     13.0
# 3      9.0
# 4     11.0
# 5     14.0
# 6      6.0
# 7      4.0
# 8     12.0
# 9      7.0
# 10     5.0
# Name: (0, x), dtype: float64

# %%
anscombe.loc[7:, idx['0', :]]
# Out:
#        0
#        x      y
# 7    4.0   4.26
# 8   12.0  10.84
# 9    7.0   4.82
# 10   5.0   5.68

# %%
anscombe.loc[:3, idx[:, 'x']]
# Out:
#       0     1     2    3
#       x     x     x    x
# 0  10.0  10.0  10.0  8.0
# 1   8.0   8.0   8.0  8.0
# 2  13.0  13.0  13.0  8.0
# 3   9.0   9.0   9.0  8.0

# %%
anscombe.loc[:3, [('0', 'x')]]
# Out:
#       0
#       x
# 0  10.0
# 1   8.0
# 2  13.0
# 3   9.0

# %%
x = anscombe.loc[:, idx['0', 'x']]
y = anscombe.loc[:, idx['0', 'y']]
x.ndim
# Out:
# 1

# %%
a, b = np.polyfit(x, y, 1)
print(a, b)
# Out:
# 0.5000909090909095 3.0000909090909076

# %%
x_t = np.array([3, 15])
y_t = a * x_t + b

# %%
plt.plot(x, y, marker='.', linestyle='none')
plt.plot(x_t, y_t)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
anscombe_x = anscombe.loc[:, idx[:, 'x']].values.T
anscombe_y = anscombe.loc[:, idx[:, 'y']].values.T
list(zip(anscombe_x, anscombe_y))
# Out:
# [(array([10.,  8., 13.,  9., 11., 14.,  6.,  4., 12.,  7.,  5.]),
#   array([ 8.04,  6.95,  7.58,  8.81,  8.33,  9.96,  7.24,  4.26, 10.84,
#           4.82,  5.68])),
#  (array([10.,  8., 13.,  9., 11., 14.,  6.,  4., 12.,  7.,  5.]),
#   array([9.14, 8.14, 8.74, 8.77, 9.26, 8.1 , 6.13, 3.1 , 9.13, 7.26, 4.74])),
#  (array([10.,  8., 13.,  9., 11., 14.,  6.,  4., 12.,  7.,  5.]),
#   array([ 7.46,  6.77, 12.74,  7.11,  7.81,  8.84,  6.08,  5.39,  8.15,
#           6.42,  5.73])),
#  (array([ 8.,  8.,  8.,  8.,  8.,  8.,  8., 19.,  8.,  8.,  8.]),
#   array([ 6.58,  5.76,  7.71,  8.84,  8.47,  7.04,  5.25, 12.5 ,  5.56,
#           7.91,  6.89]))]

# %%
for x, y in zip(anscombe_x, anscombe_y):
    a, b = np.polyfit(x, y, 1)
    print('slope:', a, 'intercept:', b)
# Out:
# slope: 0.5000909090909095 intercept: 3.0000909090909076
# slope: 0.5000000000000004 intercept: 3.000909090909089
# slope: 0.4997272727272731 intercept: 3.0024545454545453
# slope: 0.49990909090909064 intercept: 3.0017272727272735

# %%
rainfall = pd.read_csv('sheffield_weather_station.csv', sep='\s+', na_values='---', skiprows=8)
rainfall
# Out:
#       yyyy  mm  tmax  tmin    af   rain    sun
# 0     1883   1   6.3   1.7   6.0  122.1    NaN
# 1     1883   2   8.0   2.8   2.0   69.8    NaN
# 2     1883   3   4.8  -1.6  23.0   29.6    NaN
# 3     1883   4  12.2   3.8   2.0   74.0    NaN
# 4     1883   5  14.7   6.2   0.0   31.2    NaN
# 5     1883   6  17.7   9.3   0.0   66.2    NaN
# 6     1883   7  18.8  10.5   0.0   77.6    NaN
# 7     1883   8  19.8  10.9   0.0   32.5    NaN
# 8     1883   9  16.8  10.0   0.0  137.4    NaN
# 9     1883  10  12.7   6.4   0.0  102.9    NaN
# 10    1883  11   8.6   3.5   1.0   83.6    NaN
# 11    1883  12   7.3   2.4   4.0   48.6    NaN
# 12    1884   1   8.4   3.5   3.0  127.7    NaN
# 13    1884   2   8.0   2.1   3.0   49.4    NaN
# 14    1884   3   9.5   2.5   4.0   50.4    NaN
# 15    1884   4  10.6   3.3   4.0   48.0    NaN
# 16    1884   5  15.7   6.4   0.0   33.1    NaN
# 17    1884   6  18.2   8.7   0.0   39.7    NaN
# 18    1884   7  20.8  11.8   0.0   80.1    NaN
# 19    1884   8  22.6  11.8   0.0   36.8    NaN
# 20    1884   9  18.4  10.5   0.0   34.0    NaN
# 21    1884  10  12.3   6.3   0.0   36.5    NaN
# 22    1884  11   9.0   3.4   4.0   30.9    NaN
# 23    1884  12   6.6   1.7   7.0   81.6    NaN
# 24    1885   1   4.7   0.4  15.0   56.9    NaN
# 25    1885   2   8.5   2.4   5.0   76.4    NaN
# 26    1885   3   7.8   0.8  10.0   41.6    NaN
# 27    1885   4  11.6   3.4   3.0   49.5    NaN
# 28    1885   5  12.9   4.4   0.0   58.1    NaN
# 29    1885   6  18.6   9.2   0.0   76.4    NaN
# ...    ...  ..   ...   ...   ...    ...    ...
# 1572  2014   1   7.8   3.0   4.0  124.2   48.9
# 1573  2014   2   8.5   3.5   1.0  106.2   82.4
# 1574  2014   3  11.6   4.2   2.0   48.6  137.2
# 1575  2014   4  14.2   6.7   0.0   60.4  119.3
# 1576  2014   5  16.6   8.5   0.0  123.8  143.9
# 1577  2014   6  19.4  11.4   0.0   45.4  142.0
# 1578  2014   7  23.2  13.3   0.0   20.0  236.6
# 1579  2014   8  19.3  11.5   0.0   67.4  177.3
# 1580  2014   9  18.4  10.9   0.0    9.6  107.4
# 1581  2014  10  14.9   9.0   0.0   60.8   83.6
# 1582  2014  11  10.5   6.0   0.0   95.8   48.0
# 1583  2014  12   7.7   3.3   3.0  102.0   75.8
# 1584  2015   1   6.9   2.2   8.0   84.2   68.1
# 1585  2015   2   6.9   2.0   5.0   35.4   80.8
# 1586  2015   3   9.8   3.2   1.0   71.4  114.8
# 1587  2015   4  14.3   5.0   0.0   21.4  223.5
# 1588  2015   5  14.8   7.7   0.0   83.6  164.4
# 1589  2015   6  19.1  10.0   0.0   43.2  195.9
# 1590  2015   7  20.8  12.0   0.0   30.0  187.8
# 1591  2015   8  20.6  12.5   0.0   66.2  146.3
# 1592  2015   9  16.9   8.7   0.0   29.2  141.1
# 1593  2015  10  13.9   7.7   0.0   80.4   81.3
# 1594  2015  11  12.2   6.5   1.0  126.8   51.7
# 1595  2015  12  12.0   6.2   0.0  121.2   33.1
# 1596  2016   1   7.7   3.0   3.0  111.5   40.3
# 1597  2016   2   7.8   2.0   5.0   68.6   96.1
# 1598  2016   3   9.1   2.9   2.0   87.2   98.6
# 1599  2016   4  11.6   3.8   1.0   65.8  154.9
# 1600  2016   5  16.9   7.9   0.0   58.2  164.5
# 1601  2016   6  18.8  11.1   0.0  130.4  106.5
#
# [1602 rows x 7 columns]

# %%
rainfall.columns = ['year', 'month', 'tmax', 'tmin', 'af', 'rain', 'sun']

# %%
rainfall['day'] = 1

# %%
rainfall['date'] = pd.to_datetime(rainfall[['year', 'month', 'day']])

# %%
rainfall = rainfall.set_index('date')

# %%
rainfall = rainfall.loc[:'2015']
rainfall
# Out:
#             year  month  tmax  tmin    af   rain    sun  day
# date
# 1883-01-01  1883      1   6.3   1.7   6.0  122.1    NaN    1
# 1883-02-01  1883      2   8.0   2.8   2.0   69.8    NaN    1
# 1883-03-01  1883      3   4.8  -1.6  23.0   29.6    NaN    1
# 1883-04-01  1883      4  12.2   3.8   2.0   74.0    NaN    1
# 1883-05-01  1883      5  14.7   6.2   0.0   31.2    NaN    1
# 1883-06-01  1883      6  17.7   9.3   0.0   66.2    NaN    1
# 1883-07-01  1883      7  18.8  10.5   0.0   77.6    NaN    1
# 1883-08-01  1883      8  19.8  10.9   0.0   32.5    NaN    1
# 1883-09-01  1883      9  16.8  10.0   0.0  137.4    NaN    1
# 1883-10-01  1883     10  12.7   6.4   0.0  102.9    NaN    1
# 1883-11-01  1883     11   8.6   3.5   1.0   83.6    NaN    1
# 1883-12-01  1883     12   7.3   2.4   4.0   48.6    NaN    1
# 1884-01-01  1884      1   8.4   3.5   3.0  127.7    NaN    1
# 1884-02-01  1884      2   8.0   2.1   3.0   49.4    NaN    1
# 1884-03-01  1884      3   9.5   2.5   4.0   50.4    NaN    1
# 1884-04-01  1884      4  10.6   3.3   4.0   48.0    NaN    1
# 1884-05-01  1884      5  15.7   6.4   0.0   33.1    NaN    1
# 1884-06-01  1884      6  18.2   8.7   0.0   39.7    NaN    1
# 1884-07-01  1884      7  20.8  11.8   0.0   80.1    NaN    1
# 1884-08-01  1884      8  22.6  11.8   0.0   36.8    NaN    1
# 1884-09-01  1884      9  18.4  10.5   0.0   34.0    NaN    1
# 1884-10-01  1884     10  12.3   6.3   0.0   36.5    NaN    1
# 1884-11-01  1884     11   9.0   3.4   4.0   30.9    NaN    1
# 1884-12-01  1884     12   6.6   1.7   7.0   81.6    NaN    1
# 1885-01-01  1885      1   4.7   0.4  15.0   56.9    NaN    1
# 1885-02-01  1885      2   8.5   2.4   5.0   76.4    NaN    1
# 1885-03-01  1885      3   7.8   0.8  10.0   41.6    NaN    1
# 1885-04-01  1885      4  11.6   3.4   3.0   49.5    NaN    1
# 1885-05-01  1885      5  12.9   4.4   0.0   58.1    NaN    1
# 1885-06-01  1885      6  18.6   9.2   0.0   76.4    NaN    1
# ...          ...    ...   ...   ...   ...    ...    ...  ...
# 2013-07-01  2013      7  24.0  13.7   0.0   56.6  243.5    1
# 2013-08-01  2013      8  21.6  13.1   0.0   33.4  144.4    1
# 2013-09-01  2013      9  17.5  10.2   0.0   47.2  119.8    1
# 2013-10-01  2013     10  14.9   9.6   0.0  136.2   73.5    1
# 2013-11-01  2013     11   9.1   3.9   1.0   56.6   82.3    1
# 2013-12-01  2013     12   9.1   3.9   0.0   69.8   58.2    1
# 2014-01-01  2014      1   7.8   3.0   4.0  124.2   48.9    1
# 2014-02-01  2014      2   8.5   3.5   1.0  106.2   82.4    1
# 2014-03-01  2014      3  11.6   4.2   2.0   48.6  137.2    1
# 2014-04-01  2014      4  14.2   6.7   0.0   60.4  119.3    1
# 2014-05-01  2014      5  16.6   8.5   0.0  123.8  143.9    1
# 2014-06-01  2014      6  19.4  11.4   0.0   45.4  142.0    1
# 2014-07-01  2014      7  23.2  13.3   0.0   20.0  236.6    1
# 2014-08-01  2014      8  19.3  11.5   0.0   67.4  177.3    1
# 2014-09-01  2014      9  18.4  10.9   0.0    9.6  107.4    1
# 2014-10-01  2014     10  14.9   9.0   0.0   60.8   83.6    1
# 2014-11-01  2014     11  10.5   6.0   0.0   95.8   48.0    1
# 2014-12-01  2014     12   7.7   3.3   3.0  102.0   75.8    1
# 2015-01-01  2015      1   6.9   2.2   8.0   84.2   68.1    1
# 2015-02-01  2015      2   6.9   2.0   5.0   35.4   80.8    1
# 2015-03-01  2015      3   9.8   3.2   1.0   71.4  114.8    1
# 2015-04-01  2015      4  14.3   5.0   0.0   21.4  223.5    1
# 2015-05-01  2015      5  14.8   7.7   0.0   83.6  164.4    1
# 2015-06-01  2015      6  19.1  10.0   0.0   43.2  195.9    1
# 2015-07-01  2015      7  20.8  12.0   0.0   30.0  187.8    1
# 2015-08-01  2015      8  20.6  12.5   0.0   66.2  146.3    1
# 2015-09-01  2015      9  16.9   8.7   0.0   29.2  141.1    1
# 2015-10-01  2015     10  13.9   7.7   0.0   80.4   81.3    1
# 2015-11-01  2015     11  12.2   6.5   1.0  126.8   51.7    1
# 2015-12-01  2015     12  12.0   6.2   0.0  121.2   33.1    1
#
# [1596 rows x 8 columns]

# %%
rain = rainfall.rain.resample('A').sum()
rain
# Out:
# date
# 1883-12-31     875.5
# 1884-12-31     648.2
# 1885-12-31     788.1
# 1886-12-31     940.3
# 1887-12-31     491.1
# 1888-12-31     743.5
# 1889-12-31     730.1
# 1890-12-31     686.5
# 1891-12-31     878.8
# 1892-12-31     865.6
# 1893-12-31     654.9
# 1894-12-31     831.5
# 1895-12-31     798.1
# 1896-12-31     681.8
# 1897-12-31     743.8
# 1898-12-31     689.1
# 1899-12-31     752.1
# 1900-12-31     837.2
# 1901-12-31     710.6
# 1902-12-31     749.2
# 1903-12-31     967.1
# 1904-12-31     701.2
# 1905-12-31     619.0
# 1906-12-31     747.6
# 1907-12-31     803.4
# 1908-12-31     645.6
# 1909-12-31     804.1
# 1910-12-31     787.4
# 1911-12-31     646.8
# 1912-12-31     997.1
#                ...
# 1986-12-31     998.1
# 1987-12-31     789.3
# 1988-12-31     915.0
# 1989-12-31     737.1
# 1990-12-31     763.0
# 1991-12-31     666.7
# 1992-12-31     824.5
# 1993-12-31     913.8
# 1994-12-31     905.1
# 1995-12-31     667.8
# 1996-12-31     747.4
# 1997-12-31     784.7
# 1998-12-31     925.4
# 1999-12-31     880.2
# 2000-12-31    1086.9
# 2001-12-31     764.4
# 2002-12-31    1050.1
# 2003-12-31     595.2
# 2004-12-31     855.2
# 2005-12-31     726.9
# 2006-12-31     785.2
# 2007-12-31     948.8
# 2008-12-31     970.6
# 2009-12-31     896.0
# 2010-12-31     618.4
# 2011-12-31     572.4
# 2012-12-31    1146.4
# 2013-12-31     728.2
# 2014-12-31     864.2
# 2015-12-31     793.0
# Freq: A-DEC, Name: rain, Length: 133, dtype: float64

# %%
for _ in range(50):
    bs_sample = np.random.choice(rain, size=len(rain))
    x, y = ecdf(bs_sample)
    plt.plot(x, y, marker='.', linestyle='none', color='gray', alpha=0.1)
x, y = ecdf(rain)
plt.plot(x, y, marker='.')
plt.margins(0.02)
plt.xlabel('yearly rainfall (mm)')
plt.ylabel('ECDF')
plt.show()

# %%
def bootstrap_replicate_1d(data, func):
    return func(np.random.choice(data, size=len(data)))

# %%
def draw_bs_reps(data, func, size=1):
    bs_replicates = np.empty(size)
    for i in range(size):
        bs_replicates[i] = bootstrap_replicate_1d(data, func)
    return bs_replicates

# %%
bs_reps = draw_bs_reps(rain, np.mean, 10000)
sem = np.std(rain) / np.sqrt(len(rain))
bs_std = np.std(bs_reps)
print(bs_std)
plt.hist(bs_reps, bins=50, density=True)
plt.xlabel('mean annual rainfall (mm)')
plt.ylabel('PDF')
plt.show()
# Out:
# 10.358764199574095

# %%
np.percentile(bs_reps, [2.5, 97.5])
# Out:
# array([779.96900376, 820.62793233])

# %%
bs_reps = draw_bs_reps(rain, np.var, 10000)
bs_reps /= 100
plt.hist(bs_reps, density=True, bins=50)
plt.xlabel('variance of annual rainfall (sq. cm)')
plt.show()

# %%
bs_reps = draw_bs_reps(nohitter_times, np.mean, 10000)
conf_int = np.percentile(bs_reps, [2.5, 97.5])
print('95% confidence interval =', conf_int, 'games')
# Out:
# 95% confidence interval = [663.65229084 869.79741036] games

# %%
plt.hist(bs_reps, bins=50, density=True)
plt.xlabel(r'$\tau$ (games)')
plt.ylabel('PDF')
plt.show()

# %%
def draw_bs_pairs_linreg(x, y, size=1):
    inds = np.arange(len(x))
    bs_slope_reps = np.empty(size)
    bs_intercept_reps = np.empty(size)
    for i in range(size):
        bs_inds = np.random.choice(inds, size=len(inds))
        bs_x, bs_y = x[bs_inds], y[bs_inds]
        bs_slope_reps[i], bs_intercept_reps[i] = np.polyfit(bs_x, bs_y, 1)
    return bs_slope_reps, bs_intercept_reps

# %%
bs_slope_reps, bs_intercept_reps = draw_bs_pairs_linreg(illiteracy, female.fertility, 1000)

# %%
print(np.percentile(bs_slope_reps, [2.5, 97.5]))
# Out:
# [0.04389859 0.05528877]

# %%
print(np.percentile(bs_intercept_reps, [2.5, 97.5]))
# Out:
# [1.74927045 2.02741233]

# %%
plt.hist(bs_slope_reps, bins=50, density=True)
plt.xlabel('slope')
plt.ylabel('PDF')
plt.show()

# %%
plt.hist(bs_intercept_reps, bins=50, density=True)
plt.xlabel('intercept')
plt.ylabel('PDF')
plt.show()

# %%
x = np.array([0, 100])
for i in range(100):
    plt.plot(x, bs_slope_reps[i] * x + bs_intercept_reps[i], linewidth=0.5, alpha=0.2, color='red')
plt.plot(illiteracy, female.fertility, marker='.', linestyle='none')
plt.xlabel('illiteracy')
plt.ylabel('fertility')
plt.margins(0.02)
plt.show()

# %%
def permutation_sample(data1, data2):
    data = np.concatenate((data1, data2))
    permuted_data = np.random.permutation(data)
    perm_sample_1 = permuted_data[:len(data1)]
    perm_sample_2 = permuted_data[len(data1):]
    return perm_sample_1, perm_sample_2

# %%
rain_jun = rainfall.loc[rainfall.month == 6, 'rain']
rain_nov = rainfall.loc[rainfall.month == 11, 'rain']
print(rain_jun, rain_nov)
# Out:
# date
# 1883-06-01     66.2
# 1884-06-01     39.7
# 1885-06-01     76.4
# 1886-06-01     26.5
# 1887-06-01     11.2
# 1888-06-01     61.8
# 1889-06-01      6.1
# 1890-06-01     48.4
# 1891-06-01     89.2
# 1892-06-01    104.0
# 1893-06-01     34.0
# 1894-06-01     60.6
# 1895-06-01     57.1
# 1896-06-01     79.1
# 1897-06-01     90.9
# 1898-06-01     32.3
# 1899-06-01     63.8
# 1900-06-01     78.2
# 1901-06-01     27.5
# 1902-06-01     43.4
# 1903-06-01     30.1
# 1904-06-01     17.3
# 1905-06-01     77.5
# 1906-06-01     44.9
# 1907-06-01     92.2
# 1908-06-01     39.6
# 1909-06-01     79.4
# 1910-06-01     66.1
# 1911-06-01     53.5
# 1912-06-01     98.5
#               ...
# 1986-06-01     48.0
# 1987-06-01    140.0
# 1988-06-01     55.9
# 1989-06-01     54.1
# 1990-06-01     46.4
# 1991-06-01     68.6
# 1992-06-01     52.2
# 1993-06-01    108.3
# 1994-06-01     14.6
# 1995-06-01     11.3
# 1996-06-01     29.8
# 1997-06-01    130.9
# 1998-06-01    152.4
# 1999-06-01     61.0
# 2000-06-01     46.6
# 2001-06-01     43.9
# 2002-06-01     30.9
# 2003-06-01    111.1
# 2004-06-01     68.5
# 2005-06-01     42.2
# 2006-06-01      9.8
# 2007-06-01    285.6
# 2008-06-01     56.7
# 2009-06-01    168.2
# 2010-06-01     41.2
# 2011-06-01     47.8
# 2012-06-01    166.6
# 2013-06-01     37.8
# 2014-06-01     45.4
# 2015-06-01     43.2
# Name: rain, Length: 133, dtype: float64 date
# 1883-11-01     83.6
# 1884-11-01     30.9
# 1885-11-01     62.2
# 1886-11-01     37.0
# 1887-11-01     41.0
# 1888-11-01    160.2
# 1889-11-01     18.2
# 1890-11-01    122.4
# 1891-11-01     71.3
# 1892-11-01     44.2
# 1893-11-01     49.1
# 1894-11-01     37.6
# 1895-11-01    114.5
# 1896-11-01     28.8
# 1897-11-01     82.5
# 1898-11-01     71.9
# 1899-11-01     50.7
# 1900-11-01     67.7
# 1901-11-01    112.0
# 1902-11-01     63.6
# 1903-11-01     42.8
# 1904-11-01     57.2
# 1905-11-01     99.1
# 1906-11-01     86.4
# 1907-11-01     84.4
# 1908-11-01     38.1
# 1909-11-01     17.7
# 1910-11-01    102.2
# 1911-11-01    101.3
# 1912-11-01     58.0
#               ...
# 1986-11-01     93.0
# 1987-11-01     53.5
# 1988-11-01     50.5
# 1989-11-01     42.6
# 1990-11-01     47.9
# 1991-11-01     73.1
# 1992-11-01    129.1
# 1993-11-01     56.9
# 1994-11-01    103.3
# 1995-11-01     60.5
# 1996-11-01    134.3
# 1997-11-01     93.1
# 1998-11-01     49.5
# 1999-11-01     48.2
# 2000-11-01    167.9
# 2001-11-01     27.0
# 2002-11-01    111.1
# 2003-11-01     55.4
# 2004-11-01     36.2
# 2005-11-01     57.4
# 2006-11-01     66.8
# 2007-11-01     58.3
# 2008-11-01     60.0
# 2009-11-01    161.6
# 2010-11-01    112.7
# 2011-11-01     37.4
# 2012-11-01    110.6
# 2013-11-01     56.6
# 2014-11-01     95.8
# 2015-11-01    126.8
# Name: rain, Length: 133, dtype: float64

# %%
for _ in range(50):
    perm_sample_1, perm_sample_2 = permutation_sample(rain_jun, rain_nov)
    x_1, y_1 = ecdf(perm_sample_1)
    x_2, y_2 = ecdf(perm_sample_2)
    plt.plot(x_1, y_1, marker='.', linestyle='none', color='red', alpha=0.02)
    plt.plot(x_2, y_2, marker='.', linestyle='none', color='blue', alpha=0.02)
x_1, y_1 = ecdf(rain_jun)
x_2, y_2 = ecdf(rain_nov)
plt.plot(x_1, y_1, marker='.', linestyle='none', color='red')
plt.plot(x_2, y_2, marker='.', linestyle='none', color='blue')
plt.margins(0.02)
plt.xlabel('monthly rainfall (mm)')
plt.ylabel('ECDF')
plt.show()

# %%
def draw_perm_reps(data_1, data_2, func, size=1):
    perm_replicates = np.empty(size)
    for i in range(size):
        perm_sample_1, perm_sample_2 = permutation_sample(data_1, data_2)
        perm_replicates[i] = func(perm_sample_1, perm_sample_2)
    return perm_replicates

# %%
frog = pd.read_csv('frog_tongue.csv', sep=',', skiprows=14)
frog.columns
# Out:
# Index(['date', 'ID', 'trial number', 'impact force (mN)', 'impact time (ms)',
#        'impact force / body weight', 'adhesive force (mN)',
#        'time frog pulls on target (ms)', 'adhesive force / body weight',
#        'adhesive impulse (N-s)', 'total contact area (mm2)',
#        'contact area without mucus (mm2)',
#        'contact area with mucus / contact area without mucus',
#        'contact pressure (Pa)', 'adhesive strength (Pa)'],
#       dtype='object')

# %%
sns.swarmplot(x='ID', y='impact force (mN)', data=frog)
plt.xlabel('frog')
plt.ylabel('impact force (mN)')
plt.show()

# %%
def diff_of_means(data_1, data_2):
    diff = np.mean(data_1) - np.mean(data_2)
    return diff

# %%
force_b = frog.loc[frog.ID == 'IV', 'impact force (mN)']
print(type(force_b))
force_b
# Out:
# <class 'pandas.core.series.Series'>
# 60    172
# 61    142
# 62     37
# 63    453
# 64    355
# 65     22
# 66    502
# 67    273
# 68    720
# 69    582
# 70    198
# 71    198
# 72    597
# 73    516
# 74    815
# 75    402
# 76    605
# 77    711
# 78    614
# 79    468
# Name: impact force (mN), dtype: int64

# %%
force_a = frog.loc[frog.ID == 'II', 'impact force (mN)']
print(type(force_a))
force_a
# Out:
# <class 'pandas.core.series.Series'>
# 20    1612
# 21     605
# 22     327
# 23     946
# 24     541
# 25    1539
# 26     529
# 27     628
# 28    1453
# 29     297
# 30     703
# 31     269
# 32     751
# 33     245
# 34    1182
# 35     515
# 36     435
# 37     383
# 38     457
# 39     730
# Name: impact force (mN), dtype: int64

# %%
emp_diff_means = diff_of_means(force_a, force_b)
perm_replicates = draw_perm_reps(force_a, force_b, diff_of_means, size=10000)
pvalue = np.sum(perm_replicates >= emp_diff_means) / len(perm_replicates)
print('p-value =', pvalue)
# Out:
# p-value = 0.0058

# %%
translated_force_b = force_b - np.mean(force_b) + 550
bs_replicates = draw_bs_reps(translated_force_b, np.mean, 10000)
pvalue = np.sum(bs_replicates <= np.mean(force_b)) / 10000
print('p-value =', pvalue)
# Out:
# p-value = 0.0046

# %%
forces_concat = force_a.append(force_b)
forces_concat
# Out:
# 20    1612
# 21     605
# 22     327
# 23     946
# 24     541
# 25    1539
# 26     529
# 27     628
# 28    1453
# 29     297
# 30     703
# 31     269
# 32     751
# 33     245
# 34    1182
# 35     515
# 36     435
# 37     383
# 38     457
# 39     730
# 60     172
# 61     142
# 62      37
# 63     453
# 64     355
# 65      22
# 66     502
# 67     273
# 68     720
# 69     582
# 70     198
# 71     198
# 72     597
# 73     516
# 74     815
# 75     402
# 76     605
# 77     711
# 78     614
# 79     468
# Name: impact force (mN), dtype: int64

# %%
mean_force = np.mean(forces_concat)
force_a_shifted = force_a - np.mean(force_a) + mean_force
force_b_shifted = force_b - np.mean(force_b) + mean_force
bs_replicates_a = draw_bs_reps(force_a_shifted, np.mean, 10000)
bs_replicates_b = draw_bs_reps(force_b_shifted, np.mean, 10000)
bs_replicates = bs_replicates_a - bs_replicates_b
pvalue = np.sum(bs_replicates > emp_diff_means) / len(bs_replicates)
print('p-value =', pvalue)
# Out:
# p-value = 0.005

# %%
dems = np.array([True] * 153 + [False] * 91)
reps = np.array([True] * 136 + [False] * 35)
def frac_yea_dems(dems, reps):
    frac = np.sum(dems) / len(dems)
    return frac
perm_replicates = draw_perm_reps(dems, reps, frac_yea_dems, 10000)
pvalue = np.sum(perm_replicates <= 153/244) / len(perm_replicates)
print('p-value =', pvalue)
# Out:
# p-value = 0.0002

# %%
nht_dead = np.array([  
         -1,  894,   10,  130,    1,  934,   29,    6,  485,  254,  372,
         81,  191,  355,  180,  286,   47,  269,  361,  173,  246,  492,
        462, 1319,   58,  297,   31, 2970,  640,  237,  434,  570,   77,
        271,  563, 3365,   89,    0,  379,  221,  479,  367,  628,  843,
       1613, 1101,  215,  684,  814,  278,  324,  161,  219,  545,  715,
        966,  624,   29,  450,  107,   20,   91, 1325,  124, 1468,  104,
       1309,  429,   62, 1878, 1104,  123,  251,   93,  188,  983,  166,
         96,  702,   23,  524,   26,  299,   59,   39,   12,    2,  308,
       1114,  813,  887])
nht_live = np.array([ 
        645, 2088,   42, 2090,   11,  886, 1665, 1084, 2900, 2432,  750,
       4021, 1070, 1765, 1322,   26,  548, 1525,   77, 2181, 2752,  127,
       2147,  211,   41, 1575,  151,  479,  697,  557, 2267,  542,  392,
         73,  603,  233,  255,  528,  397, 1529, 1023, 1194,  462,  583,
         37,  943,  996,  480, 1497,  717,  224,  219, 1531,  498,   44,
        288,  267,  600,   52,  269, 1086,  386,  176, 2199,  216,   54,
        675, 1243,  463,  650,  171,  327,  110,  774,  509,    8,  197,
        136,   12, 1124,   64,  380,  811,  232,  192,  731,  715,  226,
        605,  539, 1491,  323,  240,  179,  702,  156,   82, 1397,  354,
        778,  603, 1001,  385,  986,  203,  149,  576,  445,  180, 1403,
        252,  675, 1351, 2983, 1568,   45,  899, 3260, 1025,   31,  100,
       2055, 4043,   79,  238, 3931, 2351,  595,  110,  215,    0,  563,
        206,  660,  242,  577,  179,  157,  192,  192, 1848,  792, 1693,
         55,  388,  225, 1134, 1172, 1555,   31, 1582, 1044,  378, 1687,
       2915,  280,  765, 2819,  511, 1521,  745, 2491,  580, 2072, 6450,
        578,  745, 1075, 1103, 1549, 1520,  138, 1202,  296,  277,  351,
        391,  950,  459,   62, 1056, 1128,  139,  420,   87,   71,  814,
        603, 1349,  162, 1027,  783,  326,  101,  876,  381,  905,  156,
        419,  239,  119,  129,  467])

# %%
nht_diff_obs = diff_of_means(nht_dead, nht_live)

# %%
perm_replicates = draw_perm_reps(nht_dead, nht_live, diff_of_means, 10000)
pvalue = np.sum(perm_replicates <= nht_diff_obs) / len(perm_replicates)
print('p-value =', pvalue)
# Out:
# p-value = 0.0002

# %%
for i in range(100):
    perm_sample_1, perm_sample_2 = permutation_sample(nht_dead, nht_live)
    x_1, y_1 = ecdf(perm_sample_1)
    x_2, y_2 = ecdf(perm_sample_2)
    plt.plot(x_1, y_1, marker='.', linestyle='none', color='red', alpha=0.02)
    plt.plot(x_2, y_2, marker='.', linestyle='none', color='blue', alpha=0.02)
x_1, y_1 = ecdf(nht_dead)
x_2, y_2 = ecdf(nht_live)
plt.plot(x_1, y_1, color='blue', linestyle='none', marker='.')
plt.plot(x_2, y_2, color='red', linestyle='none', marker='.')
plt.xlabel('No-hitter times')
plt.ylabel('ECDF')
plt.show()

# %%
r_obs = pearsonr(illiteracy, female.fertility)[0]

perm_replicates = np.empty(10000)
for i in range(10000):
    illiteracy_permuted = np.random.permutation(illiteracy)
    perm_replicates[i] = pearsonr(illiteracy_permuted, female.fertility)[0]
pvalue = np.sum(perm_replicates >= r_obs) / len(perm_replicates)
print('p-value =', pvalue)
# Out:
# p-value = 0.0

# %%
bee = pd.read_csv('bee_sperm.csv', skiprows=3)
bee
# Out:
#      Specimen  Treatment Environment  TreatmentNCSS Sample ID  Colony  Cage  \
# 0         227    Control        Cage              1    C2-1-1       2     1
# 1         228    Control        Cage              1    C2-1-2       2     1
# 2         229    Control        Cage              1    C2-1-3       2     1
# 3         230    Control        Cage              1    C2-1-4       2     1
# 4         231    Control        Cage              1    C2-1-5       2     1
# 5         232    Control        Cage              1    C2-1-6       2     1
# 6         233    Control        Cage              1    C2-1-7       2     1
# 7         234    Control        Cage              1    C2-1-8       2     1
# 8         235    Control        Cage              1    C2-1-9       2     1
# 9         236    Control        Cage              1    C2-2-1       2     2
# 10        244    Control        Cage              1   C2-2-10       2     2
# 11        237    Control        Cage              1    C2-2-2       2     2
# 12        238    Control        Cage              1    C2-2-3       2     2
# 13        239    Control        Cage              1    C2-2-4       2     2
# 14        240    Control        Cage              1    C2-2-5       2     2
# 15        241    Control        Cage              1    C2-2-6       2     2
# 16        242    Control        Cage              1    C2-2-7       2     2
# 17        243    Control        Cage              1    C2-2-8       2     2
# 18        247    Control        Cage              1    C2-3-1       2     3
# 19        255    Control        Cage              1   C2-3-10       2     3
# 20        248    Control        Cage              1    C2-3-2       2     3
# 21        249    Control        Cage              1    C2-3-3       2     3
# 22        250    Control        Cage              1    C2-3-4       2     3
# 23        256    Control        Cage              1    C2-3-5       2     3
# 24        251    Control        Cage              1    C2-3-6       2     3
# 25        252    Control        Cage              1    C2-3-7       2     3
# 26        253    Control        Cage              1    C2-3-8       2     3
# 27        254    Control        Cage              1    C2-3-9       2     3
# 28        167    Control        Cage              1    C5-1-1       5     4
# 29        168    Control        Cage              1    C5-1-2       5     4
# ..        ...        ...         ...            ...       ...     ...   ...
# 205        83    Control        Cage              1   C80-3-7      80    25
# 206        84    Control        Cage              1   C80-3-8      80    25
# 207        85    Control        Cage              1   C80-3-9      80    25
# 208       138  Pesticide        Cage              2   P84-1-1      84    26
# 209       147  Pesticide        Cage              2  P84-1-10      84    26
# 210       139  Pesticide        Cage              2   P84-1-2      84    26
# 211       140  Pesticide        Cage              2   P84-1-3      84    26
# 212       141  Pesticide        Cage              2   P84-1-4      84    26
# 213       142  Pesticide        Cage              2   P84-1-5      84    26
# 214       143  Pesticide        Cage              2   P84-1-6      84    26
# 215       144  Pesticide        Cage              2   P84-1-7      84    26
# 216       145  Pesticide        Cage              2   P84-1-8      84    26
# 217       146  Pesticide        Cage              2   P84-1-9      84    26
# 218       118  Pesticide        Cage              2   P84-2-1      84    27
# 219       119  Pesticide        Cage              2   P84-2-2      84    27
# 220       120  Pesticide        Cage              2   P84-2-3      84    27
# 221       121  Pesticide        Cage              2   P84-2-4      84    27
# 222       122  Pesticide        Cage              2   P84-2-5      84    27
# 223       123  Pesticide        Cage              2   P84-2-6      84    27
# 224       124  Pesticide        Cage              2   P84-2-7      84    27
# 225       125  Pesticide        Cage              2   P84-2-8      84    27
# 226       126  Pesticide        Cage              2   P84-2-9      84    27
# 227       148  Pesticide        Cage              2   P84-3-1      84    28
# 228       149  Pesticide        Cage              2   P84-3-2      84    28
# 229       150  Pesticide        Cage              2   P84-3-3      84    28
# 230       151  Pesticide        Cage              2   P84-3-4      84    28
# 231       152  Pesticide        Cage              2   P84-3-5      84    28
# 232       153  Pesticide        Cage              2   P84-3-6      84    28
# 233       154  Pesticide        Cage              2   P84-3-7      84    28
# 234       155  Pesticide        Cage              2   P84-3-8      84    28
#
#      Sample  Sperm Volume per 500 ul  Quantity  ViabilityRaw (%)     Quality  \
# 0         1                  2150000   2150000  96.7263814616756   96.726381
# 1         2                  2287500   2287500  96.3498079760595   96.349808
# 2         3                    87500     87500             98.75   98.750000
# 3         4                  1875000   1875000  93.2874208336941   93.287421
# 4         5                  1587500   1587500  97.7925061050061   97.792506
# 5         6                  2600000   2600000  99.3110435663627   99.311044
# 6         7                  3412500   3412500  96.9269279143752   96.926928
# 7         8                  2562500   2562500  90.4013147346481   90.401315
# 8         9                    87500     87500  97.3765432098765   97.376543
# 9         1                  1325000   1325000               100  100.000000
# 10       10                    87500     87500                50   50.000000
# 11        2                  1025000   1025000  97.4219443359481   97.421944
# 12        3                  3500000   3500000   98.952595402898   98.952595
# 13        4                  2300000   2300000  99.4550724637681   99.455072
# 14        5                  2012500   2012500  96.8066378066378   96.806638
# 15        6                  2712500   2712500  96.0334578275755   96.033458
# 16        7                  2062500   2062500  89.8484848484848   89.848485
# 17        8                        0         0  97.1783101955516         NaN
# 18        1                  2412500   2412500       95.86426295   95.864263
# 19       10                  1525000   1525000       98.83415435   98.834154
# 20        2                   387500    387500       94.53596009   94.535960
# 21        3                   200000    200000               100  100.000000
# 22        4                  3362500   3362500       96.92763298   96.927633
# 23        5                  2612500   2612500               100  100.000000
# 24        6                  3200000   3200000        97.1678744   97.167874
# 25        7                  3637500   3637500       94.02554961   94.025550
# 26        8                   625000    625000        96.9047619   96.904762
# 27        9                   200000    200000       92.06349206   92.063492
# 28        1                  4000000   4000000       44.99212781   44.992128
# 29        2                  2325000   2325000       90.58405696   90.584057
# ..      ...                      ...       ...               ...         ...
# 205       7                  2637500   2637500  77.0825689110135   77.082569
# 206       8                    20000     20000                 0    0.000000
# 207       9                   100000    100000              32.5   32.500000
# 208       1                   950000    950000       94.75378837   94.753788
# 209      10                  2487500   2487500       66.92073161   66.920732
# 210       2                  2225000   2225000       90.53494335   90.534943
# 211       3                  2150000   2150000       80.79433733   80.794337
# 212       4                  3912500   3912500       95.95850119   95.958501
# 213       5                  1125000   1125000       90.34776335   90.347763
# 214       6                   862500    862500       77.48158506   77.481585
# 215       7                  1325000   1325000       71.94325159   71.943252
# 216       8                  1062500   1062500       65.69637256   65.696373
# 217       9                  1425000   1425000        87.3019119   87.301912
# 218       1                  3700000   3700000       64.31235797   64.312358
# 219       2                   587500    587500       91.78991597   91.789916
# 220       3                  2225000   2225000       71.89373408   71.893734
# 221       4                  3025000   3025000       63.04550956   63.045510
# 222       5                  2625000   2625000        81.4469142   81.446914
# 223       6                  1700000   1700000       82.85464668   82.854647
# 224       7                   325000    325000       84.95384615   84.953846
# 225       8                  1862500   1862500       87.83734442   87.837344
# 226       9                  2662500   2662500       96.06106241   96.061062
# 227       1                  1450000   1450000       71.19408369   71.194084
# 228       2                        0         0          NO SPERM         NaN
# 229       3                  2087500   2087500       80.02419964   80.024200
# 230       4                  3500000   3500000        88.2474712   88.247471
# 231       5                  2287500   2287500                 0    0.000000
# 232       6                  2037500   2037500       89.91779766   89.917798
# 233       7                  1362500   1362500       86.33333333   86.333333
# 234       8                   912500    912500        83.9286198   83.928620
#
#      Age (d)  Infertil  AliveSperm  Quantity Millions  Alive Sperm Millions  \
# 0         14         0     2079617             2.1500              2.079617
# 1         14         0     2204001             2.2875              2.204001
# 2         14         0       86406             0.0875              0.086406
# 3         14         0     1749139             1.8750              1.749139
# 4         14         0     1552456             1.5875              1.552456
# 5         14         0     2582087             2.6000              2.582087
# 6         14         0     3307631             3.4125              3.307631
# 7         14         0     2316533             2.5625              2.316533
# 8         14         0       85204             0.0875              0.085204
# 9         14         0     1325000             1.3250              1.325000
# 10        14         0       43750             0.0875              0.043750
# 11        14         0      998574             1.0250              0.998574
# 12        14         0     3463340             3.5000              3.463340
# 13        14         0     2287466             2.3000              2.287466
# 14        14         0     1948233             2.0125              1.948233
# 15        14         0     2604907             2.7125              2.604907
# 16        14         0     1853125             2.0625              1.853125
# 17        14         1           0             0.0000              0.000000
# 18        14         0     2312725             2.4125              2.312725
# 19        14         0     1507220             1.5250              1.507220
# 20        14         0      366326             0.3875              0.366326
# 21        14         0      200000             0.2000              0.200000
# 22        14         0     3259191             3.3625              3.259191
# 23        14         0     2612500             2.6125              2.612500
# 24        14         0     3109371             3.2000              3.109371
# 25        14         0     3420179             3.6375              3.420179
# 26        14         0      605654             0.6250              0.605654
# 27        14         0      184126             0.2000              0.184126
# 28        14         0     1799685             4.0000              1.799685
# 29        14         0     2106079             2.3250              2.106079
# ..       ...       ...         ...                ...                   ...
# 205       14         0     2033052             2.6375              2.033052
# 206       14         0           0             0.0200              0.000000
# 207       14         0       32500             0.1000              0.032500
# 208       14         0      900160             0.9500              0.900160
# 209       14         0     1664653             2.4875              1.664653
# 210       14         0     2014402             2.2250              2.014402
# 211       14         0     1737078             2.1500              1.737078
# 212       14         0     3754376             3.9125              3.754376
# 213       14         0     1016412             1.1250              1.016412
# 214       14         0      668278             0.8625              0.668278
# 215       14         0      953248             1.3250              0.953248
# 216       14         0      698023             1.0625              0.698023
# 217       14         0     1244052             1.4250              1.244052
# 218       14         0     2379557             3.7000              2.379557
# 219       14         0      539265             0.5875              0.539265
# 220       14         0     1599635             2.2250              1.599635
# 221       14         0     1907126             3.0250              1.907126
# 222       14         0     2137981             2.6250              2.137981
# 223       14         0     1408528             1.7000              1.408528
# 224       14         0      276099             0.3250              0.276099
# 225       14         0     1635970             1.8625              1.635970
# 226       14         0     2557625             2.6625              2.557625
# 227       14         0     1032314             1.4500              1.032314
# 228       14         1           0             0.0000              0.000000
# 229       14         0     1670505             2.0875              1.670505
# 230       14         0     3088661             3.5000              3.088661
# 231       14         0           0             2.2875              0.000000
# 232       14         0     1832075             2.0375              1.832075
# 233       14         0     1176291             1.3625              1.176291
# 234       14         0      765848             0.9125              0.765848
#
#      Dead Sperm Millions
# 0               0.070383
# 1               0.083499
# 2               0.001094
# 3               0.125861
# 4               0.035044
# 5               0.017913
# 6               0.104869
# 7               0.245967
# 8               0.002296
# 9               0.000000
# 10              0.043750
# 11              0.026426
# 12              0.036660
# 13              0.012534
# 14              0.064267
# 15              0.107593
# 16              0.209375
# 17              0.000000
# 18              0.099775
# 19              0.017780
# 20              0.021174
# 21              0.000000
# 22              0.103309
# 23              0.000000
# 24              0.090629
# 25              0.217321
# 26              0.019346
# 27              0.015874
# 28              2.200315
# 29              0.218921
# ..                   ...
# 205             0.604448
# 206             0.020000
# 207             0.067500
# 208             0.049840
# 209             0.822847
# 210             0.210598
# 211             0.412922
# 212             0.158124
# 213             0.108588
# 214             0.194222
# 215             0.371752
# 216             0.364477
# 217             0.180948
# 218             1.320443
# 219             0.048235
# 220             0.625365
# 221             1.117874
# 222             0.487019
# 223             0.291472
# 224             0.048901
# 225             0.226530
# 226             0.104875
# 227             0.417686
# 228             0.000000
# 229             0.416995
# 230             0.411339
# 231             2.287500
# 232             0.205425
# 233             0.186209
# 234             0.146652
#
# [235 rows x 18 columns]

# %%
control = bee.loc[bee.Treatment == 'Control', 'Sperm Volume per 500 ul']
treated = bee.loc[bee.Treatment == 'Pesticide', 'Sperm Volume per 500 ul']

# %%
x_control, y_control = ecdf(control)
x_treated, y_treated = ecdf(treated)

plt.plot(x_control, y_control, marker='.', linestyle='none', color='red')
plt.plot(x_treated, y_treated, marker='.', linestyle='none', color='blue')
plt.margins(0.02)
plt.legend(('control', 'treated'), loc='lower right')
plt.xlabel('millions of alive sperms per half mL')
# Out:
# Text(0.5, 0, 'millions of alive sperms per half mL')

# %%
diff_means = np.mean(control) - np.mean(treated)
mean_count = np.mean(np.concatenate((control, treated)))
control_shifted = control - np.mean(control) + mean_count
treated_shifted = treated - np.mean(treated) + mean_count
bs_reps_control = draw_bs_reps(control_shifted, np.mean, size=10000)
bs_reps_treated = draw_bs_reps(treated_shifted, np.mean, size=10000)
bs_replicates = bs_reps_control - bs_reps_treated
pvalue = np.sum(bs_replicates >= np.mean(control) - np.mean(treated)) / len(bs_replicates)
print('p-value =', pvalue)
# Out:
# p-value = 0.0026

# %%
finch_1975 = pd.read_csv('finch_beaks_1975.csv')
finch_1975
# Out:
#       band   species  Beak length, mm  Beak depth, mm
# 0        2    fortis             9.40            8.00
# 1        9    fortis             9.20            8.30
# 2       12    fortis             9.50            7.50
# 3       15    fortis             9.50            8.00
# 4      305    fortis            11.50            9.90
# 5      307    fortis            11.10            8.60
# 6      308    fortis             9.90            8.40
# 7      309    fortis            11.50            9.80
# 8      311    fortis            10.80            9.20
# 9      312    fortis            11.30            9.00
# 10     313    fortis            11.50            9.50
# 11     314    fortis            11.50            8.90
# 12     315    fortis             9.70            8.80
# 13     316    fortis            10.90            9.70
# 14     316    fortis            10.90            9.85
# 15     320    fortis            10.10            8.90
# 16     321    fortis            10.60            8.50
# 17     323    fortis             9.60            8.20
# 18     324    fortis            10.30            9.30
# 19     326    fortis            10.50            9.10
# 20     328    fortis            10.50            8.80
# 21     329    fortis            10.90            9.40
# 22     330    fortis            11.20            9.60
# 23     340    fortis             9.40            8.50
# 24     341    fortis            10.10            8.10
# 25     342    fortis             9.60            8.00
# 26     343    fortis            10.50            9.70
# 27     344    fortis             9.90            8.20
# 28     345    fortis             9.90            8.40
# 29     346    fortis             9.60            7.90
# ..     ...       ...              ...             ...
# 373    782  scandens            13.70            8.00
# 374    783  scandens            13.90            9.10
# 375    784  scandens            13.10            8.10
# 376    806  scandens            13.40            8.30
# 377    816  scandens            13.80            8.70
# 378    890  scandens            13.60            8.80
# 379    901  scandens            14.00            8.60
# 380    916  scandens            13.50            8.70
# 381    918  scandens            12.80            8.00
# 382    920  scandens            14.00            8.80
# 383    935  scandens            13.40            9.00
# 384    953  scandens            14.90            9.10
# 385   1014  scandens            15.54            9.74
# 386   1642  scandens            14.63            9.10
# 387   1748  scandens            14.73            9.80
# 388   1841  scandens            15.73           10.40
# 389   1842  scandens            14.83            8.30
# 390   2084  scandens            15.94            9.44
# 391   2397  scandens            15.14            9.04
# 392   8110  scandens            14.23            9.00
# 393  20122  scandens            14.15            9.05
# 394  20151  scandens            14.35            9.65
# 395  20188  scandens            14.95            9.45
# 396  20210  scandens            13.95            8.65
# 397  20223  scandens            14.05            9.45
# 398  20225  scandens            14.55            9.45
# 399  20252  scandens            14.05            9.05
# 400  20255  scandens            14.45            8.75
# 401  20266  scandens            15.05            9.45
# 402  20279  scandens            13.25            8.35
#
# [403 rows x 4 columns]

# %%
finch_1975['year'] = 1975
finch_1975
# Out:
#       band   species  Beak length, mm  Beak depth, mm  year
# 0        2    fortis             9.40            8.00  1975
# 1        9    fortis             9.20            8.30  1975
# 2       12    fortis             9.50            7.50  1975
# 3       15    fortis             9.50            8.00  1975
# 4      305    fortis            11.50            9.90  1975
# 5      307    fortis            11.10            8.60  1975
# 6      308    fortis             9.90            8.40  1975
# 7      309    fortis            11.50            9.80  1975
# 8      311    fortis            10.80            9.20  1975
# 9      312    fortis            11.30            9.00  1975
# 10     313    fortis            11.50            9.50  1975
# 11     314    fortis            11.50            8.90  1975
# 12     315    fortis             9.70            8.80  1975
# 13     316    fortis            10.90            9.70  1975
# 14     316    fortis            10.90            9.85  1975
# 15     320    fortis            10.10            8.90  1975
# 16     321    fortis            10.60            8.50  1975
# 17     323    fortis             9.60            8.20  1975
# 18     324    fortis            10.30            9.30  1975
# 19     326    fortis            10.50            9.10  1975
# 20     328    fortis            10.50            8.80  1975
# 21     329    fortis            10.90            9.40  1975
# 22     330    fortis            11.20            9.60  1975
# 23     340    fortis             9.40            8.50  1975
# 24     341    fortis            10.10            8.10  1975
# 25     342    fortis             9.60            8.00  1975
# 26     343    fortis            10.50            9.70  1975
# 27     344    fortis             9.90            8.20  1975
# 28     345    fortis             9.90            8.40  1975
# 29     346    fortis             9.60            7.90  1975
# ..     ...       ...              ...             ...   ...
# 373    782  scandens            13.70            8.00  1975
# 374    783  scandens            13.90            9.10  1975
# 375    784  scandens            13.10            8.10  1975
# 376    806  scandens            13.40            8.30  1975
# 377    816  scandens            13.80            8.70  1975
# 378    890  scandens            13.60            8.80  1975
# 379    901  scandens            14.00            8.60  1975
# 380    916  scandens            13.50            8.70  1975
# 381    918  scandens            12.80            8.00  1975
# 382    920  scandens            14.00            8.80  1975
# 383    935  scandens            13.40            9.00  1975
# 384    953  scandens            14.90            9.10  1975
# 385   1014  scandens            15.54            9.74  1975
# 386   1642  scandens            14.63            9.10  1975
# 387   1748  scandens            14.73            9.80  1975
# 388   1841  scandens            15.73           10.40  1975
# 389   1842  scandens            14.83            8.30  1975
# 390   2084  scandens            15.94            9.44  1975
# 391   2397  scandens            15.14            9.04  1975
# 392   8110  scandens            14.23            9.00  1975
# 393  20122  scandens            14.15            9.05  1975
# 394  20151  scandens            14.35            9.65  1975
# 395  20188  scandens            14.95            9.45  1975
# 396  20210  scandens            13.95            8.65  1975
# 397  20223  scandens            14.05            9.45  1975
# 398  20225  scandens            14.55            9.45  1975
# 399  20252  scandens            14.05            9.05  1975
# 400  20255  scandens            14.45            8.75  1975
# 401  20266  scandens            15.05            9.45  1975
# 402  20279  scandens            13.25            8.35  1975
#
# [403 rows x 5 columns]

# %%
finch_2012 = pd.read_csv('finch_beaks_2012.csv')
finch_2012['year'] = 2012
finch_2012
# Out:
#       band   species  blength  bdepth  year
# 0    19022    fortis     10.0     8.5  2012
# 1    19028    fortis     12.5     8.9  2012
# 2    19032    fortis      9.3     7.5  2012
# 3    19041    fortis     10.3     9.6  2012
# 4    19044    fortis     11.0     9.2  2012
# 5    19048    fortis     10.1     8.2  2012
# 6    19072    fortis      9.6     7.8  2012
# 7    19082    fortis     10.9     8.6  2012
# 8    19104    fortis     10.3     8.4  2012
# 9    19114    fortis      9.8     7.7  2012
# 10   19121    fortis     10.1     8.0  2012
# 11   19126    fortis     10.4     8.7  2012
# 12   19146    fortis      9.6     8.1  2012
# 13   19164    fortis     10.6     8.8  2012
# 14   19174    fortis     10.6     9.4  2012
# 15   19203    fortis     11.9    10.0  2012
# 16   19210    fortis     11.3     9.6  2012
# 17   19217    fortis     11.3     9.6  2012
# 18   19224    fortis      9.7     8.1  2012
# 19   19226    fortis      9.7     7.5  2012
# 20   19252    fortis     10.1     8.4  2012
# 21   19263    fortis     10.0     7.9  2012
# 22   19274    fortis     10.0     8.3  2012
# 23   19280    fortis     10.0     8.9  2012
# 24   19288    fortis     11.5     9.1  2012
# 25   19328    fortis      9.5     7.7  2012
# 26   19349    fortis     11.2     8.3  2012
# 27   19362    fortis     10.7     8.6  2012
# 28   19372    fortis     10.0     8.4  2012
# 29   19382    fortis      9.8     7.7  2012
# ..     ...       ...      ...     ...   ...
# 218  21159  scandens     13.0     8.4  2012
# 219  21167  scandens     12.7     8.3  2012
# 220  21176  scandens     14.0     9.6  2012
# 221  21248  scandens     14.1     9.4  2012
# 222  21253  scandens     14.1    10.0  2012
# 223  21255  scandens     13.0     8.9  2012
# 224  21256  scandens     13.5     9.1  2012
# 225  21257  scandens     13.4     9.8  2012
# 226  21260  scandens     13.9     9.3  2012
# 227  21263  scandens     13.1     9.9  2012
# 228  21267  scandens     12.9     8.9  2012
# 229  21268  scandens     14.0     8.5  2012
# 230  21270  scandens     14.0    10.6  2012
# 231  21271  scandens     14.1     9.3  2012
# 232  21278  scandens     14.7     8.9  2012
# 233  21279  scandens     13.4     8.9  2012
# 234  21280  scandens     13.8     9.7  2012
# 235  21281  scandens     13.4     9.8  2012
# 236  21285  scandens     13.8    10.5  2012
# 237  21286  scandens     12.4     8.4  2012
# 238  21288  scandens     14.1    10.0  2012
# 239  21289  scandens     12.9     9.0  2012
# 240  21290  scandens     13.9     8.7  2012
# 241  21291  scandens     14.3     8.8  2012
# 242  21292  scandens     13.2     8.4  2012
# 243  21295  scandens     14.2     9.3  2012
# 244  21297  scandens     13.0     9.8  2012
# 245  21340  scandens     14.6     8.9  2012
# 246  21342  scandens     13.1     9.8  2012
# 247  21347  scandens     15.2     9.1  2012
#
# [248 rows x 5 columns]

# %%
finch_1975.columns = finch_2012.columns

# %%
finch = pd.concat([finch_1975, finch_2012], ignore_index=True)
finch
# Out:
#       band   species  blength  bdepth  year
# 0        2    fortis      9.4    8.00  1975
# 1        9    fortis      9.2    8.30  1975
# 2       12    fortis      9.5    7.50  1975
# 3       15    fortis      9.5    8.00  1975
# 4      305    fortis     11.5    9.90  1975
# 5      307    fortis     11.1    8.60  1975
# 6      308    fortis      9.9    8.40  1975
# 7      309    fortis     11.5    9.80  1975
# 8      311    fortis     10.8    9.20  1975
# 9      312    fortis     11.3    9.00  1975
# 10     313    fortis     11.5    9.50  1975
# 11     314    fortis     11.5    8.90  1975
# 12     315    fortis      9.7    8.80  1975
# 13     316    fortis     10.9    9.70  1975
# 14     316    fortis     10.9    9.85  1975
# 15     320    fortis     10.1    8.90  1975
# 16     321    fortis     10.6    8.50  1975
# 17     323    fortis      9.6    8.20  1975
# 18     324    fortis     10.3    9.30  1975
# 19     326    fortis     10.5    9.10  1975
# 20     328    fortis     10.5    8.80  1975
# 21     329    fortis     10.9    9.40  1975
# 22     330    fortis     11.2    9.60  1975
# 23     340    fortis      9.4    8.50  1975
# 24     341    fortis     10.1    8.10  1975
# 25     342    fortis      9.6    8.00  1975
# 26     343    fortis     10.5    9.70  1975
# 27     344    fortis      9.9    8.20  1975
# 28     345    fortis      9.9    8.40  1975
# 29     346    fortis      9.6    7.90  1975
# ..     ...       ...      ...     ...   ...
# 621  21159  scandens     13.0    8.40  2012
# 622  21167  scandens     12.7    8.30  2012
# 623  21176  scandens     14.0    9.60  2012
# 624  21248  scandens     14.1    9.40  2012
# 625  21253  scandens     14.1   10.00  2012
# 626  21255  scandens     13.0    8.90  2012
# 627  21256  scandens     13.5    9.10  2012
# 628  21257  scandens     13.4    9.80  2012
# 629  21260  scandens     13.9    9.30  2012
# 630  21263  scandens     13.1    9.90  2012
# 631  21267  scandens     12.9    8.90  2012
# 632  21268  scandens     14.0    8.50  2012
# 633  21270  scandens     14.0   10.60  2012
# 634  21271  scandens     14.1    9.30  2012
# 635  21278  scandens     14.7    8.90  2012
# 636  21279  scandens     13.4    8.90  2012
# 637  21280  scandens     13.8    9.70  2012
# 638  21281  scandens     13.4    9.80  2012
# 639  21285  scandens     13.8   10.50  2012
# 640  21286  scandens     12.4    8.40  2012
# 641  21288  scandens     14.1   10.00  2012
# 642  21289  scandens     12.9    9.00  2012
# 643  21290  scandens     13.9    8.70  2012
# 644  21291  scandens     14.3    8.80  2012
# 645  21292  scandens     13.2    8.40  2012
# 646  21295  scandens     14.2    9.30  2012
# 647  21297  scandens     13.0    9.80  2012
# 648  21340  scandens     14.6    8.90  2012
# 649  21342  scandens     13.1    9.80  2012
# 650  21347  scandens     15.2    9.10  2012
#
# [651 rows x 5 columns]

# %%
scandens = finch.loc[finch.species == 'scandens', ['blength', 'bdepth', 'year']]
scandens
# Out:
#      blength  bdepth  year
# 316    13.90     8.4  1975
# 317    14.00     8.8  1975
# 318    12.90     8.4  1975
# 319    13.50     8.0  1975
# 320    12.90     7.9  1975
# 321    14.60     8.9  1975
# 322    13.00     8.6  1975
# 323    14.20     8.5  1975
# 324    14.00     8.9  1975
# 325    14.20     9.1  1975
# 326    13.10     8.6  1975
# 327    15.10     9.8  1975
# 328    13.50     8.2  1975
# 329    14.40     9.0  1975
# 330    14.90     9.7  1975
# 331    12.90     8.6  1975
# 332    13.00     8.2  1975
# 333    14.90     9.0  1975
# 334    14.00     8.4  1975
# 335    13.80     8.6  1975
# 336    13.00     8.9  1975
# 337    14.75     9.1  1975
# 338    13.70     8.3  1975
# 339    13.80     8.7  1975
# 340    14.00     9.6  1975
# 341    14.60     8.5  1975
# 342    15.20     9.1  1975
# 343    13.50     9.0  1975
# 344    15.10     9.2  1975
# 345    15.00     9.9  1975
# ..       ...     ...   ...
# 621    13.00     8.4  2012
# 622    12.70     8.3  2012
# 623    14.00     9.6  2012
# 624    14.10     9.4  2012
# 625    14.10    10.0  2012
# 626    13.00     8.9  2012
# 627    13.50     9.1  2012
# 628    13.40     9.8  2012
# 629    13.90     9.3  2012
# 630    13.10     9.9  2012
# 631    12.90     8.9  2012
# 632    14.00     8.5  2012
# 633    14.00    10.6  2012
# 634    14.10     9.3  2012
# 635    14.70     8.9  2012
# 636    13.40     8.9  2012
# 637    13.80     9.7  2012
# 638    13.40     9.8  2012
# 639    13.80    10.5  2012
# 640    12.40     8.4  2012
# 641    14.10    10.0  2012
# 642    12.90     9.0  2012
# 643    13.90     8.7  2012
# 644    14.30     8.8  2012
# 645    13.20     8.4  2012
# 646    14.20     9.3  2012
# 647    13.00     9.8  2012
# 648    14.60     8.9  2012
# 649    13.10     9.8  2012
# 650    15.20     9.1  2012
#
# [214 rows x 3 columns]

# %%
sns.swarmplot(x='year', y='bdepth', data=scandens)
plt.xlabel('year')
plt.ylabel('beak depth (mm)')
plt.show()

# %%
bd_1975 = scandens.loc[scandens.year == 1975, 'bdepth']
bd_2012 = scandens.loc[scandens.year == 2012, 'bdepth']

# %%
x_1975, y_1975 = ecdf(bd_1975)
x_2012, y_2012 = ecdf(bd_2012)

# %%
plt.plot(x_1975, y_1975, marker='.', linestyle='none', color='red')
plt.plot(x_2012, y_2012, marker='.', linestyle='none', color='blue')
plt.margins(0.02)
plt.xlabel('beak depth (mm)')
plt.ylabel('ECDF')
plt.legend(('1975', '2012'), loc='lower right')
plt.show()

# %%
mean_diff = np.mean(bd_2012) - np.mean(bd_1975)
bs_replicates_1975 = draw_bs_reps(bd_1975, np.mean, 10000)
bs_replicates_2012 = draw_bs_reps(bd_2012, np.mean, 10000)
bs_diff_replicates = bs_replicates_2012 - bs_replicates_1975
conf_int = np.percentile(bs_diff_replicates, [2.5, 97.5])
print('difference of means =', mean_diff, 'mm')
print('95% condifence interval =', conf_int, 'mm')
# Out:
# difference of means = 0.2262204724409429 mm
# 95% condifence interval = [0.06296835 0.39198756] mm

# %%
combined_mean = np.mean(np.concatenate((bd_1975, bd_2012)))
bd_1975_shifted = bd_1975 - np.mean(bd_1975) + combined_mean
bd_2012_shifted = bd_2012 - np.mean(bd_2012) + combined_mean
bs_replicates_1975 = draw_bs_reps(bd_1975_shifted, np.mean, 10000)
bs_replicates_2012 = draw_bs_reps(bd_2012_shifted, np.mean, 10000)
bs_diff_replicates = bs_replicates_2012 - bs_replicates_1975
pvalue = np.sum(bs_diff_replicates >= mean_diff) / len(bs_diff_replicates)
print('p-value =', pvalue)
# Out:
# p-value = 0.0036

# %%
bl_1975 = scandens.loc[scandens.year == 1975, 'blength']
bl_2012 = scandens.loc[scandens.year == 2012, 'blength']

# %%
plt.plot(bl_1975, bd_1975, marker='.', linestyle='none', color='blue', alpha=0.5)
plt.plot(bl_2012, bd_2012, marker='.', linestyle='none', color='red', alpha=0.5)
plt.xlabel('beak length (mm)')
plt.ylabel('beak depth (mm)')
plt.legend(('1975', '2012'), loc='upper left')
plt.show()

# %%
slope_1975, intercept_1975 = np.polyfit(bl_1975, bd_1975, 1)
slope_2012, intercept_2012 = np.polyfit(bl_2012, bd_2012, 1)

# %%
bs_slope_reps_1975, bs_intercept_reps_1975 = draw_bs_pairs_linreg(bl_1975.array, bd_1975.array, 1000)
bs_slope_reps_2012, bs_intercept_reps_2012 = draw_bs_pairs_linreg(bl_2012.array, bd_2012.array, 1000)

# %%
slope_conf_int_1975 = np.percentile(bs_slope_reps_1975, [2.5, 97.5])
slope_conf_int_2012 = np.percentile(bs_slope_reps_2012, [2.5, 97.5])
intercept_conf_int_1975 = np.percentile(bs_intercept_reps_1975, [2.5, 97.5])
intercept_conf_int_2012 = np.percentile(bs_intercept_reps_2012, [2.5, 97.5])
print('1975: slope =', slope_1975, 'conf int =', slope_conf_int_1975)
print('1975: intercept =', intercept_1975, 'conf int =', intercept_conf_int_1975)
print('2012: slope =', slope_2012, 'conf int =', slope_conf_int_2012)
print('2012: intercept =', intercept_2012, 'conf int =', intercept_conf_int_2012)
# Out:
# 1975: slope = 0.4652051691605937 conf int = [0.33294308 0.59371062]
# 1975: intercept = 2.3908752365842267 conf int = [0.59474788 4.27529724]
# 2012: slope = 0.462630358835313 conf int = [0.33896898 0.59248944]
# 2012: intercept = 2.9772474982360198 conf int = [1.24681161 4.62900917]

# %%
plt.plot(bl_1975, bd_1975, marker='.', linestyle='none', color='blue', alpha=0.5)
plt.plot(bl_2012, bd_2012, marker='.', linestyle='none', color='red', alpha=0.5)
plt.xlabel('bleak length (mm)')
plt.ylabel('bleak depth (mm)')
plt.legend(('1975', '2012'), loc='upper left')
x = np.array([10, 17])
for i in range(100):
    plt.plot(x, bs_slope_reps_1975[i] * x + bs_intercept_reps_1975[i],
            linewidth=0.5, alpha=0.2, color='blue')
    plt.plot(x, bs_slope_reps_2012[i] * x + bs_intercept_reps_2012[i],
            linewidth=0.5, alpha=0.2, color='red')
plt.show()

# %%
ratio_1975 = bl_1975 / bd_1975
ratio_2012 = bl_2012 / bd_2012

# %%
mean_ratio_1975 = np.mean(ratio_1975)
mean_ratio_2012 = np.mean(ratio_2012)

# %%
bs_replicates_1975 = draw_bs_reps(ratio_1975, np.mean, 10000)
bs_replicates_2012 = draw_bs_reps(ratio_2012, np.mean, 10000)

# %%
conf_int_1975 = np.percentile(bs_replicates_1975, [0.5, 99.5])
conf_int_2012 = np.percentile(bs_replicates_2012, [0.5, 99.5])

# %%
print('1975: mean ratio =', mean_ratio_1975,
      'conf int =', conf_int_1975)
print('2012: mean ratio =', mean_ratio_2012,
      'conf int =', conf_int_2012)
# Out:
# 1975: mean ratio = 1.5788823771858533 conf int = [1.5563146  1.60171038]
# 2012: mean ratio = 1.4658342276847778 conf int = [1.44392177 1.48758069]

# %%
fortis = pd.read_csv('fortis_beak_depth_heredity.csv')
fortis
# Out:
#      Mid-offspr  Male BD  Female BD
# 0         10.70    10.90       9.30
# 1          9.78    10.70       8.40
# 2          9.48    10.70       8.10
# 3          9.60    10.70       9.80
# 4         10.27     9.85      10.40
# 5          9.50     9.80       9.60
# 6          9.00     9.90       8.20
# 7          7.46     9.30       5.50
# 8          7.65     9.40       8.60
# 9          8.63     9.40       7.90
# 10         9.81     9.40       9.85
# 11         9.40    10.10       9.70
# 12         9.48    10.10       9.00
# 13         8.75     8.30       9.80
# 14         7.60     8.70       8.00
# 15        10.00    10.10      10.10
# 16        10.09    10.10      10.10
# 17         9.74     9.70      10.10
# 18         9.64     9.70      10.75
# 19         8.49    11.80       8.20
# 20        10.15    10.40      10.70
# 21        10.28    10.50      10.40
# 22         9.20    10.30       8.10
# 23        10.01    10.30      10.10
# 24         9.03     8.60       9.30
# 25         9.94     9.50      10.60
# 26        10.50    10.00      10.40
# 27         9.70    10.00       9.00
# 28        10.02     9.10      10.75
# 29        10.04    11.20       8.70
# ..          ...      ...        ...
# 383       10.40    10.10      10.10
# 384        9.65     9.40       9.30
# 385        8.80     9.40       8.30
# 386        8.65     9.10       8.40
# 387        9.70     9.90       9.35
# 388        9.23     9.50       9.00
# 389        9.43     9.30       9.80
# 390        9.93    10.35      10.30
# 391        8.47     9.80       7.30
# 392        9.55     9.80       9.55
# 393        9.28     9.50       8.80
# 394        8.85     9.60       8.40
# 395        8.90    10.10       9.20
# 396        8.75     8.50       8.70
# 397        8.63     9.25       8.35
# 398        9.00     8.70       9.30
# 399        9.43    10.30       9.60
# 400        8.28     8.90       7.90
# 401        9.23     9.50       9.20
# 402       10.40    10.10      10.50
# 403        9.00     8.30       9.80
# 404        9.80     9.45      10.50
# 405        9.77    10.80       9.15
# 406        8.97     8.50       8.80
# 407        8.37     8.80       8.65
# 408        7.70     7.40       9.00
# 409        7.90     7.40       8.30
# 410        9.50     8.85       8.70
# 411        8.20     9.30       7.70
# 412        8.80     9.40       9.40
#
# [413 rows x 3 columns]

# %%
scandens = pd.read_csv('scandens_beak_depth_heredity.csv')
scandens
# Out:
#      mid_parent  mid_offspring
# 0        8.3318         8.4190
# 1        8.4035         9.2468
# 2        8.5317         8.1532
# 3        8.7202         8.0089
# 4        8.7089         8.2215
# 5        8.7541         8.3734
# 6        8.7730         8.5025
# 7        8.8107         8.6392
# 8        8.7919         8.7684
# 9        8.8069         8.8139
# 10       8.6523         8.7911
# 11       8.6146         8.9051
# 12       8.6938         8.9203
# 13       8.7127         8.8747
# 14       8.7466         8.9430
# 15       8.7504         9.0038
# 16       8.7805         8.9810
# 17       8.7428         9.0949
# 18       8.7164         9.2696
# 19       8.8032         9.1633
# 20       8.8258         9.1785
# 21       8.8560         9.1937
# 22       8.9012         9.2772
# 23       8.9125         9.0722
# 24       8.8635         8.9658
# 25       8.8258         8.9658
# 26       8.8522         8.5025
# 27       8.8974         8.4949
# 28       8.9427         8.4949
# 29       8.9879         8.5633
# ..          ...            ...
# 100      9.5535         9.6266
# 101      9.4668         9.6038
# 102      9.3725         9.4063
# 103      9.3348         9.2316
# 104      9.3763         9.3380
# 105      9.3839         9.2620
# 106      9.4216         9.2620
# 107      9.4065         9.4063
# 108      9.3348         9.4367
# 109      9.4442         9.0342
# 110      9.4367         8.9430
# 111      9.5083         8.9203
# 112      9.4480         8.7835
# 113      9.4781         8.7835
# 114      9.5950         9.0570
# 115      9.6101         8.9354
# 116      9.5686         8.8975
# 117      9.6365         8.8139
# 118      9.7119         8.8671
# 119      9.8213         9.0873
# 120      9.8250         9.2848
# 121      9.7609         9.2392
# 122      9.6516         9.2924
# 123      9.5988         9.4063
# 124      9.5460         9.3152
# 125      9.6516         9.4899
# 126      9.7572         9.5962
# 127      9.8854         9.6873
# 128     10.0023         9.5203
# 129      9.3914         9.6646
#
# [130 rows x 2 columns]

# %%
bd_parent_fortis = (fortis['Male BD'] + fortis['Female BD']) / 2
bd_offspring_fortis = fortis['Mid-offspr']

# %%
bd_parent_scandens = scandens.mid_parent
bd_offspring_scandens = scandens.mid_offspring

# %%
plt.plot(bd_parent_fortis, bd_offspring_fortis,
             marker='.', linestyle='none', color='blue', alpha=0.5)
plt.plot(bd_parent_scandens, bd_offspring_scandens,
             marker='.', linestyle='none', color='red', alpha=0.5)
plt.xlabel('parental beak depth (mm)')
plt.ylabel('offspring beak depth (mm)')
plt.legend(('G. fortis', 'G. scandens'), loc='lower right')
plt.show()

# %%
def draw_bs_pairs(x, y, func, size=1):
    inds = np.arange(len(x))
    bs_replicates = np.empty(size)
    for i in range(size):
        bs_inds = np.random.choice(inds, size=len(inds))
        bs_x, bs_y = x[bs_inds], y[bs_inds]
        bs_replicates[i] = func(bs_x, bs_y)
    return bs_replicates

# %%
r_scandens = pearsonr(bd_parent_scandens, bd_offspring_scandens)[0]
r_fortis = pearsonr(bd_parent_fortis, bd_offspring_fortis)[0]

# %%
def pearson_r(data_1, data_2):
    return np.corrcoef(data_1, data_2)[0,1]

# %%
bs_replicates_scandens = draw_bs_pairs(bd_parent_scandens, bd_offspring_scandens, pearson_r, 1000)
bs_replicates_fortis = draw_bs_pairs(bd_parent_fortis, bd_offspring_fortis, pearson_r, 1000)

# %%
conf_int_scandens = np.percentile(bs_replicates_scandens, [2.5, 97.5])
conf_int_fortis = np.percentile(bs_replicates_fortis, [2.5, 97.5])

# %%
print('G. scandens:', r_scandens, conf_int_scandens)
print('G. fortis:', r_fortis, conf_int_fortis)
# Out:
# G. scandens: 0.41170636294012597 [0.26516627 0.54337216]
# G. fortis: 0.7283412395518485 [0.66747609 0.78073044]

# %%
def heritability(parents, offspring):
    covariance_matrix = np.cov(parents, offspring)
    return covariance_matrix[0, 1] / covariance_matrix[0, 0]

# %%
heritability_scandens = heritability(bd_parent_scandens, bd_offspring_scandens)
heritability_fortis = heritability(bd_parent_fortis, bd_offspring_fortis)

# %%
replicates_scandens = draw_bs_pairs(bd_parent_scandens, bd_offspring_scandens, heritability, size=1000)
replicates_fortis = draw_bs_pairs(bd_parent_fortis, bd_offspring_fortis, heritability, size=1000)

# %%
conf_int_scandens = np.percentile(replicates_scandens,[2.5,97.5])
conf_int_fortis = np.percentile(replicates_fortis,[2.5,97.5])

# %%
print('G. scandens:', heritability_scandens, conf_int_scandens)
print('G. fortis:', heritability_fortis, conf_int_fortis)
# Out:
# G. scandens: 0.5485340868685982 [0.34638859 0.75040316]
# G. fortis: 0.7229051911438156 [0.64462749 0.79161853]

# %%
perm_replicates = np.empty(10000)
for i in range(10000):
    bd_parent_permuted = np.random.permutation(bd_parent_scandens)
    perm_replicates[i] = heritability(bd_parent_permuted, bd_offspring_scandens)
pvalue = np.sum(perm_replicates >= heritability_scandens) / len(perm_replicates)
print('p-value =', pvalue)
# Out:
# p-value = 0.0
